# %%
import pandas as pd

df = pd.read_csv("../data/processed/aqi_weather_timeseries.csv")

# Convert timestamp to datetime
df["timestamp"] = pd.to_datetime(df["timestamp"])

# Sort by time
df = df.sort_values("timestamp")

df.head(), df.shape
# Out:
# (      city  predicted_aqi  temperature  humidity  wind_speed  \
#  0  Silchar         56.015         18.8      64.0         3.6
#  1  Silchar         56.015         18.8      64.0         3.6
#  2  Silchar         56.015         18.8      64.0         3.6
#  3  Silchar         56.015         18.8      64.0         3.6
#  4  Silchar         56.015         18.8      64.0         3.6
#
#              timestamp
#  0 2026-01-18 18:21:29
#  1 2026-01-18 18:21:35
#  2 2026-01-18 18:21:38
#  3 2026-01-18 18:21:40
#  4 2026-01-18 18:21:43  ,
#  (777, 6))

# %%
features = ["predicted_aqi", "temperature", "humidity", "wind_speed"]
data = df[features].values

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# %%
import numpy as np

SEQ_LENGTH = 8   # last 8 timesteps
X, y = [], []

for i in range(len(data_scaled) - SEQ_LENGTH):
    X.append(data_scaled[i:i+SEQ_LENGTH])
    y.append(data_scaled[i+SEQ_LENGTH][0])  # predict AQI only

X = np.array(X)
y = np.array(y)

X.shape, y.shape
# Out:
# ((769, 8, 4), (769,))

# %%
split = int(0.8 * len(X))

X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(SEQ_LENGTH, X.shape[2])),
    LSTM(32),
    Dense(1)
])

model.compile(optimizer="adam", loss="mse")
model.summary()
# Out:
# C:\Users\prash\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 8, 64)               │          17,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 30,113 (117.63 KB)
#  Trainable params: 30,113 (117.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train, y_train, epochs=30, batch_size=16, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0473 - val_loss: 0.0246
# Epoch 2/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0355 - val_loss: 0.0189
# Epoch 3/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0326 - val_loss: 0.0174
# Epoch 4/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0298 - val_loss: 0.0171
# Epoch 5/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0295 - val_loss: 0.0145
# Epoch 6/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0346 - val_loss: 0.0151
# Epoch 7/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0247 - val_loss: 0.0183
# Epoch 8/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0245 - val_loss: 0.0113
# Epoch 9/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0205 - val_loss: 0.0102
# Epoch 10/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0177 - val_loss: 0.0110
# Epoch 11/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0149 - val_loss: 0.0130
# Epoch 12/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0164 - val_loss: 0.0089
# Epoch 13/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0157 - val_loss: 0.0113
# Epoch 14/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0190 - val_loss: 0.0098
# Epoch 15/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0150 - val_loss: 0.0120
# Epoch 16/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0156 - val_loss: 0.0116
# Epoch 17/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0134 - val_loss: 0.0086
# Epoch 18/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0158 - val_loss: 0.0092
# Epoch 19/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0162 - val_loss: 0.0093
# Epoch 20/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0157 - val_loss: 0.0121
# Epoch 21/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0157 - val_loss: 0.0127
# Epoch 22/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0181 - val_loss: 0.0098
# Epoch 23/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0131 - val_loss: 0.0084
# Epoch 24/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0133 - val_loss: 0.0083
# Epoch 25/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0208 - val_loss: 0.0083
# Epoch 26/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0171 - val_loss: 0.0089
# Epoch 27/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0129 - val_loss: 0.0091
# Epoch 28/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0156 - val_loss: 0.0090
# Epoch 29/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0126 - val_loss: 0.0101
# Epoch 30/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0140 - val_loss: 0.0106

# %%
model.save("../models/aqi_lstm_forecast.h5")

import joblib
joblib.dump(scaler, "../models/aqi_lstm_scaler.pkl")

print("LSTM model saved")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# LSTM model saved
